# %% [markdown]
# ## 📊 Trade and News Data Analysis
#
# This notebook loads the combined trade log and scraper data from `data_analysis.csv` into a Pandas DataFrame. The table below shows all trades enriched with corresponding company news and metadata.
#
# - **Trade data includes:**
#   timestamp, symbol, price at detection, 5-minute low price, price jump (%), 5-minute volume, number of trades per second, average volume per second, and 1-second price difference.
#
# - **Scraper data includes:**
#   news title, news URL, news date and time, price impact, news content and summary, market capitalization, float, insider and institutional ownership percentages, short interest percentage, industry, sector, website, country, and city.

# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas as pd

# Load the CSV into a DataFrame
df = pd.read_csv("data_analysis.csv", encoding="utf-8-sig")

# Show the full DataFrame
df.head(20)  # You can use df instead to display the full table if small
# Out:
#                   timestamp symbol  price_at_detection  low_price_5min  \
# 0   2025-09-09 11:07:34,235   AMBO                3.69            3.32
# 1   2025-09-09 12:13:09,237   CPOP                1.39            1.24
# 2   2025-09-09 12:30:10,587    CWD                2.40            2.16
# 3   2025-09-09 13:00:49,216    ADN                3.61            3.20
# 4   2025-09-09 13:01:09,508   HCWB                4.32            3.81
# 5   2025-09-09 13:01:43,565   REVB                3.17            2.85
# 6   2025-09-09 13:07:12,402   YMAT                1.42            1.27
# 7   2025-09-09 13:12:21,929   NCNA                3.03            2.86
# 8   2025-09-09 13:17:31,739   CERO                4.93            4.70
# 9   2025-09-09 13:30:09,473    BON                1.67            1.59
# 10  2025-09-11 11:37:39,303   AMST                3.43            3.33
# 11  2025-09-11 12:00:14,851   SLXN                5.46            4.61
# ...
